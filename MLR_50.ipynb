# %% [markdown]
# <a href="https://colab.research.google.com/github/74527mohammad/Python/blob/main/MLR_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot

# %%
df = pd.read_csv("/content/50_Startups.csv")
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
#EDA
data = df.rename({"R&D Spend":"RNDS","Administration":"ADS","Marketing Spend":"MKS"},axis=1)
data
# Out:
#          RNDS        ADS        MKS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [RNDS, ADS, MKS, State, Profit]
# Index: []

# %%
data.describe()
# Out:
#                 RNDS            ADS            MKS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
data.corr()
# Out:
# <ipython-input-17-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             RNDS       ADS       MKS    Profit
# RNDS    1.000000  0.241955  0.724248  0.972900
# ADS     0.241955  1.000000 -0.032154  0.200717
# MKS     0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.set_style(style="darkgrid")
sns.pairplot(data)

# %%
model = smf.ols("Profit~RNDS+ADS+MKS",data=data).fit()

# %%
model.params
# Out:
# Intercept    50122.192990
# RNDS             0.805715
# ADS             -0.026816
# MKS              0.027228
# dtype: float64

# %%
model.tvalues, np.round(model.pvalues,5)
# Out:
# (Intercept     7.626218
#  RNDS         17.846374
#  ADS          -0.525507
#  MKS           1.655077
#  dtype: float64,
#  Intercept    0.00000
#  RNDS         0.00000
#  ADS          0.60176
#  MKS          0.10472
#  dtype: float64)

# %%
model.rsquared, model.rsquared_adj
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
slr_a = smf.ols("Profit~ADS",data=data).fit()
slr_a.tvalues , slr_a.pvalues
# Out:
# (Intercept    3.040044
#  ADS          1.419493
#  dtype: float64,
#  Intercept    0.003824
#  ADS          0.162217
#  dtype: float64)

# %%
slr_m = smf.ols("Profit~MKS",data=data).fit()
slr_m.tvalues, slr_m.pvalues
# Out:
# (Intercept    7.808356
#  MKS          7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  MKS          4.381073e-10
#  dtype: float64)

# %%
mlr_am = smf.ols("Profit~ADS+MKS",data=data).fit()
mlr_am.tvalues, mlr_am.pvalues
# Out:
# (Intercept    1.142741
#  ADS          2.467779
#  MKS          8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  ADS          1.729198e-02
#  MKS          9.727245e-11
#  dtype: float64)

# %%
#model validation
rsq_r=smf.ols("RNDS~ADS+MKS",data=data).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("ADS~RNDS+MKS",data=data).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("MKS~RNDS+ADS",data=data).fit().rsquared
vif_m=1/(1-rsq_m)

# Putting the values in Dataframe format
d1={'Variables':['RNDS','ADS','MKS'],'Vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0      RNDS  2.468903
# 1       ADS  1.175091
# 2       MKS  2.326773

# %%
sm.qqplot(model.resid,line="q")
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49])]

# %%
def standard_values(vals):
  return(vals-vals.mean())/vals.std()

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title("Residual plot")
plt.xlabel("Standardized fitted values")
plt.ylabel("Standardized residual values")
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"RNDS",fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"ADS",fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,"MKS",fig=fig)
plt.show()

# %%
#checking outliers and influencers

(c,_) = model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data)),np.round(c,5))
plt.xlabel("Row Index")
plt.ylabel("Cook Distance")
plt.show()

# %%
np.argmax(c),np.max(c)
# Out:
# (49, 0.2880822927543272)

# %%
influence_plot(model)
plt.show()

# %%
x = data.shape[1]
y = data.shape[0]
leverage_cutoff = (3*(x+1))/y
leverage_cutoff
# Out:
# 0.36

# %%
#as we know pt.49 is an influence
data[data.index.isin([49])]
# Out:
#     RNDS       ADS       MKS       State   Profit
# 49   0.0  116983.8  45173.06  California  14681.4

# %%
data1 = data.drop(data.index[[49]],axis=0).reset_index(drop=True)
data1
# Out:
#          RNDS        ADS        MKS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
#for final model
model2 = smf.ols("Profit~ADS+RNDS+MKS",data=data1).fit()

# %%
while model2.rsquared < 0.99:
  for c in [np.max(c)>1]:
    model2 = smf.ols("Profit~RNDS+MKS+ADS",data=data1).fit()
    (c,_) = model2.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data1 = data1.drop(data1.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data1

  else:
    final_model = smf.ols("Profit~ADS+RNDS+MKS",data = data1).fit()
    final_model.rsquared , final_model.aic
    print("Therefore the model accuracy is increased to",final_model.rsquared)
# Out:
# Therefore the model accuracy is increased to 0.962593650298269
# Therefore the model accuracy is increased to 0.9638487279209413
# Therefore the model accuracy is increased to 0.9663901957918793
# Therefore the model accuracy is increased to 0.9706076169779905
# Therefore the model accuracy is increased to 0.9727840588916423
# Therefore the model accuracy is increased to 0.9734292907181952
# Therefore the model accuracy is increased to 0.9785801571833451
# Therefore the model accuracy is increased to 0.9777383743090916
# Therefore the model accuracy is increased to 0.9790510088977512
# Therefore the model accuracy is increased to 0.9790004461890552
# Therefore the model accuracy is increased to 0.9807878666153609
# Therefore the model accuracy is increased to 0.9838299343609735
# Therefore the model accuracy is increased to 0.983114992639277
# Therefore the model accuracy is increased to 0.9833768520972176
# Therefore the model accuracy is increased to 0.9878892536376698
# ...

# %%
final_model.rsquared
# Out:
# 0.9882757054424702

# %%
data1
# Out:
#          RNDS        ADS        MKS       State     Profit
# 0   142107.34   91391.77  366168.42     Florida  166187.94
# 1   131876.90   99814.71  362861.36    New York  156991.12
# 2   130298.13  145530.06  323876.68     Florida  155752.60
# 3   120542.52  148718.95  311613.29    New York  152211.77
# 4   123334.88  108679.17  304981.62  California  149759.96
# 5    91992.39  135495.07  252664.93  California  134307.35
# 6    94657.16  145077.58  282574.31    New York  125370.37
# 7    91749.16  114175.79  294919.57     Florida  124266.90
# 8    76253.86  113867.30  298664.47  California  118474.03
# 9    67532.53  105751.03  304768.73     Florida  108733.99
# 10   77044.01   99281.34  140574.81    New York  108552.04
# 11   64664.71  139553.16  137962.62  California  107404.34
# 12   75328.87  144135.98  134050.07     Florida  105733.54
# 13   66051.52  182645.56  118148.20     Florida  103282.38
# 14   65605.48  153032.06  107138.38    New York  101004.64
# ...

# %%
#model prediction
new_data = pd.DataFrame({"RNDS":50000,"ADS":100000,"MKS":300000},index=[0])
new_data
# Out:
#     RNDS     ADS     MKS
# 0  50000  100000  300000

# %%
final_model.predict(new_data)
# Out:
# 0    98795.05565
# dtype: float64

# %%
pred_y = final_model.predict(data1)
pred_y
# Out:
# 0     165589.539700
# 1     158552.826483
# 2     156789.000710
# 3     149524.698853
# 4     150122.356712
# 5     126598.769555
# 6     130104.785747
# 7     127878.387928
# 8     117298.757074
# 9     111329.242429
# 10    110009.916133
# 11    102331.717613
# 12    109661.804131
# 13    103462.767086
# 14    101874.612012
# 15     97655.794577
# 16     97872.919535
# 17     96858.382686
# 18     98654.449007
# 19     93583.600868
# 20     91186.568204
# 21     88571.938968
# 22     84521.312916
# 23     78528.002935
# 24     76670.262623
# 25     73237.524757
# 26     68075.710756
# dtype: float64

# %%
#now for r^2 value for model prepared
d2 = {"Prep_models":["model","Final_model"],"Rsquared":[model.rsquared,final_model.rsquared]}
table = pd.DataFrame(d2)
table
# Out:
#    Prep_models  Rsquared
# 0        model  0.950746
# 1  Final_model  0.988276
